# %% [markdown]
# # ML lecture 9: Tips for traning DNN
#
# ** Do not always blame overfiting **
#
# Ooverfiting is not the bigest problem in deep learning.
#
# More layers proformance better than less layers, but needs more training time.
#
# ## Recipe for deep learning
# Input is random, output has already converge.
#
# ** Reason: Vanishing Gradient Problem. **
#
# Solution Below!
#
# ### ReLU
# <img src="ReLU.jpg" width = "300" height = "200" alt="ReLU" align=center />
# Thin the network by taking out small gradients.
#
# Handle vanishing problem!!!
#
# ### Maxout (linear network)
#
# ** learnable activation function **
#
# Like max pooling on neron instead of image
#
# ReLU is a special case of maxout, but more than ReLU.
#
# ### Hard to find opical network parameters
#
# Momentum
# <img src="Moment.jpg" width = "300" height = "200" alt="Momentum" align=center />
# Adam = RMSProp + Momentum
#
# ### Regularization
#
# New loss function to be minimized
#
# L2 regularization:
# <img src="L2reg.jpg" width = "200" height = "40" alt="L2" align=center />
# New gradient:
# <img src="Graof%20L2.jpg" width = "300" height = "60" alt="GraL2" align=center />
# L1 regularization:
# <img src="L1reg.jpg" width = "170" height = "34" alt="L2" align=center />
# New gradient:
# <img src="Graof%20L1.jpg" width = "300" height = "60" alt="GraL2" align=center />
#
# #### Weight Decay
# Our brain prunes out the useless link between neurons when grew older.
#
# ### Dropout
# Each time before updating the parameters, dropout some usless nerons.
#
# ** Testing ** : No dropout
#
# if the dropout rate is p%, all the weight times (1 - p)%
#
#
# ![re.jpg](attachment:re.jpg)
